# %% [markdown]
# ## Import Dependencies and Initiate Lat/Lng Ranges

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import gmaps

# Import API key
from api_keys import gkey
from api_keys import wkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV/TXT)
output_data_file = "output_data/cities.csv"
output_txt_file = "output_data/cities.txt"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []
latitude = []
longitude = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)
        latitude.append(lat_lng[0])
        longitude.append(lat_lng[1])

# %%
with open(output_txt_file, "w") as myfile:
    myfile.write(f"Latitudinal Weather Analysis\n")
    myfile.write(f"{len(cities)} unique cities")
    myfile.write("\n")

# Print the city count to confirm sufficient count
print(f"Latitudinal Weather Analysis")
print(f"{len(cities)} unique cities")
# Out:
# Latitudinal Weather Analysis
# 618 unique cities

# %% [markdown]
# ## Perform Open Weather Map API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wkey

# %%
# Get weather information that will be used for further analysis
not_found = []
found = []
weather = []

for x in range(len(cities)):
    city = cities[x].replace(' ', '+')
    country = countries[x]
    location = f"{city},{country}"
    city_url = f"{url}&q={location}"

    response = requests.get(city_url).json()
    try:
        temp = response['main']['temp_max']
        humidity = response['main']['humidity']
        cloudiness = response['clouds']['all']
        windSpeed = response['wind']['speed']
        locationLat = response['coord']['lat']
        locationLng = response['coord']['lon']
        name = response['name']
        country = response['sys']['country']
        date = response['dt']
        numId = response['id']
        information = {
            'city': name,
            'country': country,
            'ID': numId,
            'date': date,
            'temperature': temp,
            'humidity': humidity,
            'cloudiness': cloudiness,
            'wind speed': windSpeed,
            'latitude': locationLat,
            'longitude': locationLng
        }
        with open(output_txt_file, "a") as myfile:
            myfile.write(f"Location: {name}, {country}. City ID: {numId}\n")
            myfile.write(f"{city_url}\n")
            myfile.write("\n")
        print(f"Location: {name}, {country}. City ID: {numId}")
        print(f"{city_url}")
        print("\n")
        found.append(location)
        weather.append(information)
    except KeyError:
        loc = location.replace('+', ' ').replace(',', ', ')
        with open(output_txt_file, "a") as myfile:
            myfile.write(f"Location: {loc} has no weather data\n")
            myfile.write(f"{city_url}\n")
            myfile.write("\n")
        print(f"Location: {loc} has no weather data")
        print(f"{city_url}")
        print("\n")
        not_found.append(location)

with open(output_txt_file, "a") as myfile:
    myfile.write(f"Found by Open Weather Map: {len(found)}\n")
    myfile.write(f"Not found by Open Weather Map: {len(not_found)}\n")
    myfile.write("\n")
print(f"Found by Open Weather Map: {len(found)}")
print(f"Not found by Open Weather Map: {len(not_found)}")
print("\n")
# Out:
# Location: Grand Gaube, MU. City ID: 934479
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=grand+gaube,mu
#
#
# Location: Albany, AU. City ID: 2077963
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=albany,au
#
#
# Location: Puerto Ayora, EC. City ID: 3652764
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=puerto+ayora,ec
#
#
# Location: Kavaratti, IN. City ID: 1267390
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kavaratti,in
#
#
# Location: Kuryk, KZ. City ID: 609919
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kuryk,kz
#
#
# Location: mys shmidta, ru has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mys+shmidta,ru
#
#
# Location: Semnan, IR. City ID: 116402
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=semnan,ir
#
#
# Location: Kodiak, US. City ID: 4407665
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kodiak,us
#
#
# Location: Mar del Plata, AR. City ID: 3863379
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mar+del+plata,ar
#
#
# Location: Cidreira, BR. City ID: 3466165
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cidreira,br
#
#
# Location: San Patricio, MX. City ID: 3985168
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=san+patricio,mx
#
#
# Location: Cherskiy, RU. City ID: 2126199
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cherskiy,ru
#
#
# Location: Vaini, TO. City ID: 4032243
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=vaini,to
#
#
# Location: Kaka, TM. City ID: 161901
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kaka,tm
#
#
# Location: Provideniya, RU. City ID: 4031574
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=provideniya,ru
#
#
# Location: Coihaique, CL. City ID: 3894426
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=coihaique,cl
#
#
# Location: Agasegyhaza, HU. City ID: 3056391
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=agasegyhaza,hu
#
#
# Location: Butaritari, KI. City ID: 2110227
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=butaritari,ki
#
#
# Location: mataura, pf has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mataura,pf
#
#
# Location: Yellowknife, CA. City ID: 6185377
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=yellowknife,ca
#
#
# Location: Harper, LR. City ID: 2276492
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=harper,lr
#
#
# Location: Busselton, AU. City ID: 2075265
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=busselton,au
#
#
# Location: Palmer, US. City ID: 5871146
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=palmer,us
#
#
# Location: Klaksvik, FO. City ID: 2618795
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=klaksvik,fo
#
#
# Location: Chuy, UY. City ID: 3443061
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=chuy,uy
#
#
# Location: Rikitea, PF. City ID: 4030556
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=rikitea,pf
#
#
# Location: Henties Bay, NA. City ID: 3356832
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=henties+bay,na
#
#
# Location: Saint-Philippe, RE. City ID: 935215
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=saint-philippe,re
#
#
# Location: Mahebourg, MU. City ID: 934322
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mahebourg,mu
#
#
# Location: Cape Town, ZA. City ID: 3369157
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cape+town,za
#
#
# Location: samusu, ws has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=samusu,ws
#
#
# Location: Nikolskoye, RU. City ID: 546105
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=nikolskoye,ru
#
#
# Location: Castro, CL. City ID: 3896218
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=castro,cl
#
#
# Location: Thompson, CA. City ID: 6165406
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=thompson,ca
#
#
# Location: Medicine Hat, CA. City ID: 6071618
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=medicine+hat,ca
#
#
# Location: phumi samraong, kh has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=phumi+samraong,kh
#
#
# Location: Dingle, IE. City ID: 2964782
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=dingle,ie
#
#
# Location: Avarua, CK. City ID: 4035715
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=avarua,ck
#
#
# Location: Port Alfred, ZA. City ID: 964432
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=port+alfred,za
#
#
# Location: attawapiskat, ca has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=attawapiskat,ca
#
#
# Location: Le Port, RE. City ID: 935616
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=le+port,re
#
#
# Location: Tiksi, RU. City ID: 2015306
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tiksi,ru
#
#
# Location: Kencong, ID. City ID: 1632358
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kencong,id
#
#
# Location: Kaitangata, NZ. City ID: 2208248
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kaitangata,nz
#
#
# Location: Atuona, PF. City ID: 4020109
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=atuona,pf
#
#
# Location: Hattiesburg, US. City ID: 4429295
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=hattiesburg,us
#
#
# Location: Barrow, US. City ID: 4252975
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=barrow,us
#
#
# Location: Cabo San Lucas, MX. City ID: 3985710
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cabo+san+lucas,mx
#
#
# Location: saleaula, ws has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=saleaula,ws
#
#
# Location: Hithadhoo, MV. City ID: 1282256
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=hithadhoo,mv
#
#
# Location: dolbeau, ca has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=dolbeau,ca
#
#
# Location: belushya guba, ru has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=belushya+guba,ru
# Location: San Vicente, PH. City ID: 1687428
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=san+vicente,ph
#
#
# Location: Tananger, NO. City ID: 3134865
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tananger,no
#
#
# Location: Qasigiannguit, GL. City ID: 3420768
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=qasigiannguit,gl
#
#
# Location: Waipawa, NZ. City ID: 2185329
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=waipawa,nz
#
#
# Location: Alta Floresta, BR. City ID: 6316343
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=lebu,cl
#
#
# Location: Hecun, CN. City ID: 1808749
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=hecun,cn
#
#
# Location: Kota Kinabalu, MY. City ID: 1733432
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kota+kinabalu,my
#
#
# Location: Turukhansk, RU. City ID: 1488903
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=turukhansk,ru
#
#
# Location: zhitikara, kz has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=zhitikara,kz
#
#
# Location: nizhneyansk, ru has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=nizhneyansk,ru
#
#
# Location: Aleppo, SY. City ID: 170063
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=aleppo,sy
#
#
# Location: Hilo, US. City ID: 5855927
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=hilo,us
#
#
# Location: Matadi, CD. City ID: 2313002
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=matadi,cd
#
#
# Location: Bambous Virieux, MU. City ID: 1106677
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=bambous+virieux,mu
#
#
# Location: Sao Joao da Barra, BR. City ID: 3448903
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=sao+joao+da+barra,br
#
#
# Location: Kremenchuk, UA. City ID: 704147
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kremenchuk,ua
# Location: Vestmannaeyjar, IS. City ID: 3412093
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=vestmannaeyjar,is
#
#
# Location: Dikson, RU. City ID: 1507390
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=dikson,ru
#
#
# Location: Meulaboh, ID. City ID: 1214488
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=meulaboh,id
#
#
# Location: Rosario do Sul, BR. City ID: 3450873
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=rosario+do+sul,br
#
#
# Location: Vila Velha, BR. City ID: 6320062
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=vila+velha,br
#
#
# Location: bengkulu, id has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=bengkulu,id
#
#
# Location: Kaeo, NZ. City ID: 2189343
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kaeo,nz
#
#
# Location: Baiyin, CN. City ID: 1817240
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=baiyin,cn
#
#
# Location: Sosnovo-Ozerskoye, RU. City ID: 2016216
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=sosnovo-ozerskoye,ru
#
#
# Location: Port Lincoln, AU. City ID: 2063036
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=port+lincoln,au
#
#
# Location: Pangnirtung, CA. City ID: 6096551
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=pangnirtung,ca
#
#
# Location: Tual, ID. City ID: 1623197
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tual,id
#
#
# Location: kuche, cn has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kuche,cn
#
#
# Location: Puerto Escondido, MX. City ID: 3520994
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=puerto+escondido,mx
#
#
# Location: Cochrane, CA. City ID: 5924618
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cochrane,ca
#
#
# Location: Victoria, SC. City ID: 241131
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=victoria,sc
#
#
# Location: qabis, tn has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=qabis,tn
#
#
# Location: mahaicony, gy has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mahaicony,gy
#
#
# Location: sentyabrskiy, ru has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=sentyabrskiy,ru
#
#
# Location: airai, pw has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=airai,pw
#
#
# Location: Yablonovo, RU. City ID: 578283
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=yablonovo,ru
#
#
# Location: Semey, KZ. City ID: 1519422
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=semey,kz
#
#
# Location: cozumel, mx has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cozumel,mx
#
#
# Location: Manuk Mangkaw, PH. City ID: 1701394
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=manuk+mangkaw,ph
#
#
# Location: Wageningen, SR. City ID: 3382783
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=wageningen,sr
#
#
# Location: Novotroitsk, RU. City ID: 517836
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=novotroitsk,ru
#
#
# Location: Santa Helena de Goias, BR. City ID: 3450206
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=santa+helena+de+goias,br
#
#
# Location: tsihombe, mg has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tsihombe,mg
#
#
# Location: Ulaanbaatar, MN. City ID: 2028462
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ulaanbaatar,mn
#
#
# Location: Fayaoue, NC. City ID: 2141305
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=fayaoue,nc
#
#
# Location: Smithers, CA. City ID: 6149996
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=smithers,ca
#
#
# Location: Dwarka, IN. City ID: 1273294
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=dwarka,in
#
#
# Location: East London, ZA. City ID: 1006984
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=east+london,za
#
#
# Location: Sahibganj, IN. City ID: 1257794
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=santa+lucia,es
#
#
# Location: Yerbogachen, RU. City ID: 2012956
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=yerbogachen,ru
#
#
# Location: Salalah, OM. City ID: 286621
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=salalah,om
#
#
# Location: Naryan-Mar, RU. City ID: 523392
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=naryan-mar,ru
#
#
# Location: Bluff, NZ. City ID: 2206939
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=bluff,nz
#
#
# Location: La Ronge, CA. City ID: 6050066
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=la+ronge,ca
#
#
# Location: Cherepovets, RU. City ID: 569223
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cherepovets,ru
#
#
# Location: Matara, LK. City ID: 1235846
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=matara,lk
#
#
# Location: Evensk, RU. City ID: 2125693
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=evensk,ru
#
#
# Location: Ban Bung, TH. City ID: 1608418
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ban+bung,th
#
#
# Location: Teknaf, BD. City ID: 1185095
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=teknaf,bd
#
#
# Location: Tucupita, VE. City ID: 3625929
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tucupita,ve
#
#
# Location: Torbay, CA. City ID: 6167817
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=torbay,ca
#
#
# Location: Kuito, AO. City ID: 3348078
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kuito,ao
#
#
# Location: Tasiilaq, GL. City ID: 3424607
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tasiilaq,gl
#
#
# Location: Lagoa, PT. City ID: 2267254
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=lagoa,pt
#
#
# Location: vaitupu, wf has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=vaitupu,wf
#
#
# Location: Atikokan, CA. City ID: 5888001
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=atikokan,ca
#
#
# Location: Eyl, SO. City ID: 60019
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=eyl,so
#
#
# Location: Dunmore Town, BS. City ID: 3572462
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=dunmore+town,bs
#
#
# Location: tidore, id has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tidore,id
#
#
# Location: Ozernovskiy, RU. City ID: 2122293
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ozernovskiy,ru
#
#
# Location: Katherine, AU. City ID: 2068655
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=katherine,au
#
#
# Location: sakakah, sa has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=sakakah,sa
#
#
# Location: Hasaki, JP. City ID: 2112802
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=hasaki,jp
#
#
# Location: Karlshamn, SE. City ID: 2701727
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=karlshamn,se
#
#
# Location: Aksarka, RU. City ID: 1512019
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=aksarka,ru
#
#
# Location: Aswan, EG. City ID: 359792
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=aswan,eg
# Location: Watsa, CD. City ID: 204283
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=watsa,cd
#
#
# Location: Alice Town, BS. City ID: 3572924
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=alice+town,bs
#
#
# Location: Porto Walter, BR. City ID: 3662761
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=porto+walter,br
#
#
# Location: Christiana, ZA. City ID: 1013550
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=christiana,za
#
#
# Location: Grand-Santi, GF. City ID: 3381538
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=grand-santi,gf
#
#
# Location: Broome, AU. City ID: 2075720
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=broome,au
#
#
# Location: Eureka, US. City ID: 5563397
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=eureka,us
#
#
# Location: asfi, ma has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=asfi,ma
#
#
# Location: Ossora, RU. City ID: 2122389
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ossora,ru
#
#
# Location: bur gabo, so has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=bur+gabo,so
#
#
# Location: Puerto Colombia, CO. City ID: 3671497
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=puerto+colombia,co
#
#
# Location: Bella Union, UY. City ID: 3443631
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=bella+union,uy
#
#
# Location: bolungarvik, is has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=bolungarvik,is
#
#
# Location: Ribas do Rio Pardo, BR. City ID: 3451399
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ribas+do+rio+pardo,br
#
#
# Location: Chapada dos Guimaraes, BR. City ID: 3466307
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=chapada+dos+guimaraes,br
#
#
# Location: akyab, mm has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=akyab,mm
#
#
# Location: Xichang, CN. City ID: 1789647
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=xichang,cn
#
#
# Location: Lerici, IT. City ID: 3174856
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=lerici,it
#
#
# Location: samalaeulu, ws has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=samalaeulu,ws
#
#
# Location: Takab, IR. City ID: 113508
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=takab,ir
#
#
# Location: Narsaq, GL. City ID: 3421719
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=narsaq,gl
#
#
# Location: Aykhal, RU. City ID: 2027296
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=aykhal,ru
#
#
# Location: grand river south east, mu has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=grand+river+south+east,mu
#
#
# Location: Naantali, FI. City ID: 645212
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=naantali,fi
#
#
# Location: Petropavlovsk-Kamchatskiy, RU. City ID: 2122104
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=petropavlovsk-kamchatskiy,ru
#
#
# Location: Wattegama, LK. City ID: 1241622
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=wattegama,lk
#
#
# Location: Batagay, RU. City ID: 2027044
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=batagay,ru
#
#
# Location: olafsvik, is has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=olafsvik,is
#
#
# Location: Carnarvon, AU. City ID: 2074865
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=carnarvon,au
#
#
# Location: Mercedes, AR. City ID: 3430709
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mercedes,ar
#
#
# Location: Ritchie, ZA. City ID: 961226
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ritchie,za
#
#
# Location: Amazar, RU. City ID: 2027806
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=amazar,ru
#
#
# Location: Balabac, PH. City ID: 1728675
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=balabac,ph
#
#
# Location: Barreirinhas, BR. City ID: 3406196
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=barreirinhas,br
#
#
# Location: tarudant, ma has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tarudant,ma
#
#
# Location: Namibe, AO. City ID: 3347019
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=namibe,ao
#
#
# Location: Port-Gentil, GA. City ID: 2396518
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=port-gentil,ga
#
#
# Location: Lieksa, FI. City ID: 648090
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=lieksa,fi
#
#
# Location: Lerwick, GB. City ID: 2644605
# ...
#
#
# Location: Howard Springs, AU. City ID: 6301965
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=howard+springs,au
#
#
# Location: Kourou, GF. City ID: 3381303
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kourou,gf
#
#
# Location: Hambantota, LK. City ID: 1244926
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=hambantota,lk
#
#
# Location: Gashua, NG. City ID: 2341656
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=gashua,ng
#
#
# Location: Ha Tinh, VN. City ID: 1581047
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ha+tinh,vn
#
#
# Location: Cairns, AU. City ID: 2172797
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cairns,au
#
#
# Location: West Bay, KY. City ID: 3580477
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=west+bay,ky
# Location: Naze, JP. City ID: 1855540
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=naze,jp
#
#
# Location: goderich, sl has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=goderich,sl
#
#
# Location: Borovskoy, KZ. City ID: 1525121
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=borovskoy,kz
#
#
# Location: Clarksburg, US. City ID: 4802316
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=clarksburg,us
#
#
# Location: Agadir, MA. City ID: 2561668
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=agadir,ma
#
#
# Location: Phan Thiet, VN. City ID: 1571058
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=phan+thiet,vn
#
#
# Location: Mitsamiouli, KM. City ID: 921786
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mitsamiouli,km
#
#
# Location: Moose Factory, CA. City ID: 6078372
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=moose+factory,ca
#
#
# Location: Beyneu, KZ. City ID: 610298
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=beyneu,kz
#
#
# Location: Poum, NC. City ID: 2138555
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=poum,nc
#
#
# Location: syracuse, it has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=syracuse,it
#
#
# Location: Gambela, ET. City ID: 337405
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=gambela,et
#
#
# Location: japura, br has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=japura,br
#
#
# Location: Yulara, AU. City ID: 6355222
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=yulara,au
#
#
# Location: Ribeira Grande, PT. City ID: 3372707
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ribeira+grande,pt
#
#
# Location: Lesozavodsk, RU. City ID: 2020812
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=lesozavodsk,ru
#
#
# Location: Shyryayeve, UA. City ID: 694016
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=shyryayeve,ua
#
#
# Location: Ketchikan, US. City ID: 5554428
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ketchikan,us
#
#
# Location: Medea, DZ. City ID: 2488835
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=medea,dz
#
#
# Location: Asyut, EG. City ID: 359783
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=asyut,eg
#
#
# Location: Saint-Augustin, CA. City ID: 6138501
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=saint-augustin,ca
#
#
# Location: Lazaro Cardenas, MX. City ID: 3996234
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=lazaro+cardenas,mx
#
#
# Location: asau, tv has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=asau,tv
#
#
# Location: Finschhafen, PG. City ID: 2097418
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=finschhafen,pg
#
#
# Location: Qazanbulaq, AZ. City ID: 586112
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=qazanbulaq,az
#
#
# Location: Alofi, NU. City ID: 4036284
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=alofi,nu
#
#
# Location: Saint-Pierre, PM. City ID: 3424934
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=saint-pierre,pm
#
#
# Location: huazolotitlan, mx has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=huazolotitlan,mx
#
#
# Location: Nara, ML. City ID: 6779095
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=nara,ml
#
#
# Location: Srednekolymsk, RU. City ID: 2121025
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=srednekolymsk,ru
#
#
# Location: Ramanuj Ganj, IN. City ID: 1258731
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ramanuj+ganj,in
#
#
# Location: Vilyuysk, RU. City ID: 2013392
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=vilyuysk,ru
#
#
# Location: Palauig, PH. City ID: 1696188
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=palauig,ph
#
#
# Location: Kashan, IR. City ID: 128477
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kashan,ir
#
#
# Location: Campbellsville, US. City ID: 4286717
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=campbellsville,us
#
#
# Location: Khasan, RU. City ID: 2039557
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=khasan,ru
#
#
# Location: Snezhnogorsk, RU. City ID: 795243
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=snezhnogorsk,ru
#
#
# Location: Pignon, HT. City ID: 3718834
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=pignon,ht
#
#
# Location: Cukai, MY. City ID: 1732945
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cukai,my
#
#
# Location: Along, IN. City ID: 1278969
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=along,in
#
#
# Location: Roebourne, AU. City ID: 2062276
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=roebourne,au
#
#
# Location: scottsburgh, za has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=scottsburgh,za
#
#
# Location: Meadow Lake, CA. City ID: 6071421
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=meadow+lake,ca
#
#
# Location: Marfino, RU. City ID: 503977
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=marfino,ru
#
#
# Location: Aksu, CN. City ID: 1529660
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=aksu,cn
#
#
# Location: Diamantino, BR. City ID: 3464724
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=diamantino,br
#
#
# Location: Piacabucu, BR. City ID: 3454005
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=piacabucu,br
#
#
# Location: khonuu, ru has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=khonuu,ru
#
#
# Location: Verkhnyaya Inta, RU. City ID: 1487332
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=verkhnyaya+inta,ru
#
#
# Location: Trairi, BR. City ID: 3386177
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=trairi,br
#
#
# Location: Matagami, CA. City ID: 6067747
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=matagami,ca
#
#
# Location: Touros, BR. City ID: 3386213
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=touros,br
#
#
# Location: Minab, IR. City ID: 123941
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=minab,ir
# Location: parras, mx has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=parras,mx
#
#
# Location: cabo rojo, us has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cabo+rojo,us
#
#
# Location: San Cristobal, EC. City ID: 3652567
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=san+cristobal,ec
#
#
# Location: laguna, br has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=laguna,br
#
#
# Location: Muravlenko, RU. City ID: 1540711
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=muravlenko,ru
#
#
# Location: Navalmoral de la Mata, ES. City ID: 2513324
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=navalmoral+de+la+mata,es
#
#
# Location: mrirt, ma has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mrirt,ma
#
#
# Location: Tymovskoye, RU. City ID: 2120334
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=tymovskoye,ru
#
#
# Location: Hammerfest, NO. City ID: 779683
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=hammerfest,no
#
#
# Location: Chubbuck, US. City ID: 5588842
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=chubbuck,us
#
#
# Location: chagda, ru has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=chagda,ru
#
#
# Location: acarau, br has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=acarau,br
#
#
# Location: Maposeni, TZ. City ID: 878073
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=maposeni,tz
#
#
# Location: Worland, US. City ID: 5843495
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=worland,us
#
#
# Location: Lumby, CA. City ID: 6061958
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=lumby,ca
#
#
# Location: kemijarvi, fi has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=kemijarvi,fi
#
#
# Location: Shubarshi, KZ. City ID: 608270
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=shubarshi,kz
#
#
# Location: Knysna, ZA. City ID: 988698
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=knysna,za
#
#
# Location: Sumbe, AO. City ID: 3346015
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=sumbe,ao
#
#
# Location: Balarampur, IN. City ID: 1277634
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=balarampur,in
#
#
# Location: Fatezh, RU. City ID: 563300
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=fatezh,ru
#
#
# Location: Cabedelo, BR. City ID: 3404558
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cabedelo,br
#
#
# Location: Askino, RU. City ID: 580577
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=askino,ru
#
#
# Location: Gimli, CA. City ID: 5961417
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=gimli,ca
#
#
# Location: Mackay, AU. City ID: 2159220
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=mackay,au
#
#
# Location: Praia, CV. City ID: 3374333
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=praia,cv
#
#
# Location: Shebalino, RU. City ID: 1492299
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=shebalino,ru
#
#
# Location: requena, pe has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=requena,pe
#
#
# Location: Arman, RU. City ID: 2127060
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=arman,ru
#
#
# Location: Marawi, SD. City ID: 370481
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=marawi,sd
#
#
# Location: Palembang, ID. City ID: 1633070
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=palembang,id
#
#
# Location: Rio Sereno, PA. City ID: 3701810
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=rio+sereno,pa
#
#
# Location: Cookeville, US. City ID: 4615145
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=cookeville,us
#
#
# Location: Icod de los Vinos, ES. City ID: 2516474
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=icod+de+los+vinos,es
#
#
# Location: Rio Gallegos, AR. City ID: 3838859
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=rio+gallegos,ar
#
#
# Location: Middelburg, ZA. City ID: 976361
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=middelburg,za
#
#
# Location: ginda, er has no weather data
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=ginda,er
#
#
# Location: Shaoguan, CN. City ID: 1795874
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=shaoguan,cn
#
#
# Location: Dafeng, CN. City ID: 1813088
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=dafeng,cn
#
#
# Location: Laje, BR. City ID: 3456450
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a3a0fd86ccd3117b69e5a75b54b43bf&q=laje,br
#
#
# Found by Open Weather Map: 537
# Not found by Open Weather Map: 81

# %% [markdown]
# ## Perform Google Geocoding API Calls for Locations Not Found By Weather API

# %%
# Performing analysis of cities that weren't found
# Pulling lat/lng from Google Geocode
geocode_found = []
geocode_not_found = []

for nf in not_found:
    city = nf.split(',')[0]
    country = nf.split(',')[1]
    target_url = f"https://maps.googleapis.com/maps/api/geocode/json?address=%s" \
    "&sensor=false&components=country:%s&key=%s" % (city, country, gkey)
    geo_data = requests.get(target_url).json()
    try:
        try:
            name = geo_data['results'][0]['formatted_address']
            lat = geo_data['results'][0]['geometry']['location']['lat']
            lng = geo_data['results'][0]['geometry']['location']['lng']
            approx = geo_data['results'][0]['partial_match']
        except KeyError:
            approx = False
        info = {
            'location' : name,
            'latitude' : lat,
            'longitude' : lng,
            'approximate' : approx,
            'search term' : nf
        }
        with open(output_txt_file, "a") as myfile:
            myfile.write(f"Location: {name}\n")
            myfile.write(f"{target_url}\n")
            myfile.write("\n")
        print(f"Location: {name}")
        print(f"{target_url}")
        print("\n")
        geocode_found.append(info)
    except:
        geocode_not_found.append(nf)

with open(output_txt_file, "a") as myfile:
    myfile.write(f"Searching {len(not_found)} cities for Lat/Lng\n")
    myfile.write(f"{len(geocode_found)} cities found by Google Geocoding\n")
    myfile.write(f"{len(geocode_not_found)} cities not found by Google Geocoding\n")
    myfile.write("\n")
# Out:
# Location: Mys Shmidta, Chukotka Autonomous Okrug, Russia, 689350
# https://maps.googleapis.com/maps/api/geocode/json?address=mys+shmidta&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Mata'ura, French Polynesia
# https://maps.googleapis.com/maps/api/geocode/json?address=mataura&sensor=false&components=country:pf&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Samusu, Samoa
# https://maps.googleapis.com/maps/api/geocode/json?address=samusu&sensor=false&components=country:ws&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Krong Samraong, Cambodia
# https://maps.googleapis.com/maps/api/geocode/json?address=phumi+samraong&sensor=false&components=country:kh&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Attawapiskat, ON, Canada
# https://maps.googleapis.com/maps/api/geocode/json?address=attawapiskat&sensor=false&components=country:ca&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Sale'aula, Samoa
# https://maps.googleapis.com/maps/api/geocode/json?address=saleaula&sensor=false&components=country:ws&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Dolbeau-Mistassini, QC, Canada
# https://maps.googleapis.com/maps/api/geocode/json?address=dolbeau&sensor=false&components=country:ca&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Belushya Guba, Arkhangelsk Oblast, Russia
# https://maps.googleapis.com/maps/api/geocode/json?address=belushya+guba&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Villingili, Maldives
# https://maps.googleapis.com/maps/api/geocode/json?address=viligili&sensor=false&components=country:mv&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Phan Rang–Tháp Chàm, Ninh Thuan Province, Vietnam
# https://maps.googleapis.com/maps/api/geocode/json?address=phan+rang&sensor=false&components=country:vn&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Taolagnaro, Madagascar
# https://maps.googleapis.com/maps/api/geocode/json?address=taolanaro&sensor=false&components=country:mg&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Codrington, Antigua and Barbuda
# https://maps.googleapis.com/maps/api/geocode/json?address=codrington&sensor=false&components=country:ag&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Ittoqqortoormiit, Greenland
# https://maps.googleapis.com/maps/api/geocode/json?address=illoqqortoormiut&sensor=false&components=country:gl&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Tumanny, Murmansk Oblast, Russia, 184375
# https://maps.googleapis.com/maps/api/geocode/json?address=tumannyy&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Touggourt, Algeria
# https://maps.googleapis.com/maps/api/geocode/json?address=tuggurt&sensor=false&components=country:dz&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Ghat, Libya
# https://maps.googleapis.com/maps/api/geocode/json?address=gat&sensor=false&components=country:ly&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Amderma, Nenets Autonomous Okrug, Russia, 166744
# https://maps.googleapis.com/maps/api/geocode/json?address=amderma&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Zhetikara 110000, Kazakhstan
# https://maps.googleapis.com/maps/api/geocode/json?address=zhitikara&sensor=false&components=country:kz&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Nizhneyansk, Sakha Republic, Russia, 678562
# https://maps.googleapis.com/maps/api/geocode/json?address=nizhneyansk&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Bengkulu, Bengkulu City, Bengkulu, Indonesia
# https://maps.googleapis.com/maps/api/geocode/json?address=bengkulu&sensor=false&components=country:id&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Kuqa, Aksu, Xinjiang, China
# https://maps.googleapis.com/maps/api/geocode/json?address=kuche&sensor=false&components=country:cn&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Gabes, Tunisia
# https://maps.googleapis.com/maps/api/geocode/json?address=qabis&sensor=false&components=country:tn&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Mahaicony, Guyana
# https://maps.googleapis.com/maps/api/geocode/json?address=mahaicony&sensor=false&components=country:gy&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Sentyabr'skiy, Khanty-Mansi Autonomous Okrug, Russia, 628330
# https://maps.googleapis.com/maps/api/geocode/json?address=sentyabrskiy&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Airai, Palau
# https://maps.googleapis.com/maps/api/geocode/json?address=airai&sensor=false&components=country:pw&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Cozumel, Quintana Roo, Mexico
# https://maps.googleapis.com/maps/api/geocode/json?address=cozumel&sensor=false&components=country:mx&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Tsiombe, Madagascar
# https://maps.googleapis.com/maps/api/geocode/json?address=tsihombe&sensor=false&components=country:mg&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Vaitupu, Wallis and Futuna
# https://maps.googleapis.com/maps/api/geocode/json?address=vaitupu&sensor=false&components=country:wf&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Tidore, Tidore Kepulauan City, North Maluku, Indonesia
# https://maps.googleapis.com/maps/api/geocode/json?address=tidore&sensor=false&components=country:id&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Sakaka Saudi Arabia
# https://maps.googleapis.com/maps/api/geocode/json?address=sakakah&sensor=false&components=country:sa&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Safi, Morocco
# https://maps.googleapis.com/maps/api/geocode/json?address=asfi&sensor=false&components=country:ma&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Raas Cabaad, Somalia
# https://maps.googleapis.com/maps/api/geocode/json?address=bur+gabo&sensor=false&components=country:so&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Bolungarvík, Iceland
# https://maps.googleapis.com/maps/api/geocode/json?address=bolungarvik&sensor=false&components=country:is&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Sittwe, Myanmar (Burma)
# https://maps.googleapis.com/maps/api/geocode/json?address=akyab&sensor=false&components=country:mm&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Samalae'ulu, Samoa
# https://maps.googleapis.com/maps/api/geocode/json?address=samalaeulu&sensor=false&components=country:ws&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Grand River South East, Mauritius
# https://maps.googleapis.com/maps/api/geocode/json?address=grand+river+south+east&sensor=false&components=country:mu&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Ólafsvík, Iceland
# https://maps.googleapis.com/maps/api/geocode/json?address=olafsvik&sensor=false&components=country:is&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Taroudant, Morocco
# https://maps.googleapis.com/maps/api/geocode/json?address=tarudant&sensor=false&components=country:ma&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Dianópolis - State of Tocantins, 77300-000, Brazil
# https://maps.googleapis.com/maps/api/geocode/json?address=dianopolis&sensor=false&components=country:br&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Embi, Kazakhstan
# https://maps.googleapis.com/maps/api/geocode/json?address=emba&sensor=false&components=country:kz&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Altônia - State of Paraná, 87550-000, Brazil
# https://maps.googleapis.com/maps/api/geocode/json?address=altonia&sensor=false&components=country:br&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Kadykchan, Magadan Oblast, Russia, 686332
# https://maps.googleapis.com/maps/api/geocode/json?address=kadykchan&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Samana 32000, Dominican Republic
# https://maps.googleapis.com/maps/api/geocode/json?address=samana&sensor=false&components=country:do&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Pelabuhan Ratu, Sukabumi, West Java, Indonesia
# https://maps.googleapis.com/maps/api/geocode/json?address=palabuhanratu&sensor=false&components=country:id&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
# Location: St. Anthony, NL, Canada
# https://maps.googleapis.com/maps/api/geocode/json?address=saint+anthony&sensor=false&components=country:ca&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Solomon Islands
# https://maps.googleapis.com/maps/api/geocode/json?address=lata&sensor=false&components=country:sb&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Sayalgudi, Tamil Nadu, India
# https://maps.googleapis.com/maps/api/geocode/json?address=sayalgudi&sensor=false&components=country:in&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Port Vila, Vanuatu
# https://maps.googleapis.com/maps/api/geocode/json?address=vila&sensor=false&components=country:vu&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Tuvalu
# https://maps.googleapis.com/maps/api/geocode/json?address=lolua&sensor=false&components=country:tv&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Sidi Kacem, Morocco
# https://maps.googleapis.com/maps/api/geocode/json?address=sidi+qasim&sensor=false&components=country:ma&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Kismayo, Somalia
# https://maps.googleapis.com/maps/api/geocode/json?address=kismayo&sensor=false&components=country:so&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: El Alto, Peru
# https://maps.googleapis.com/maps/api/geocode/json?address=el+alto&sensor=false&components=country:pe&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Rungata, Kiribati
# https://maps.googleapis.com/maps/api/geocode/json?address=rungata&sensor=false&components=country:ki&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Saint Stephen, NB, Canada
# https://maps.googleapis.com/maps/api/geocode/json?address=saint+stephen&sensor=false&components=country:ca&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Kos'ya, Sverdlovsk Oblast, Russia, 624239
# https://maps.googleapis.com/maps/api/geocode/json?address=kosya&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Barentsburg, Svalbard and Jan Mayen
# https://maps.googleapis.com/maps/api/geocode/json?address=barentsburg&sensor=false&components=country:sj&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Nam Tha River, Laos
# https://maps.googleapis.com/maps/api/geocode/json?address=nam+tha&sensor=false&components=country:la&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Marcona District, Peru
# https://maps.googleapis.com/maps/api/geocode/json?address=marcona&sensor=false&components=country:pe&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Ouargla, Algeria
# https://maps.googleapis.com/maps/api/geocode/json?address=warqla&sensor=false&components=country:dz&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Toliara, Madagascar
# https://maps.googleapis.com/maps/api/geocode/json?address=toliary&sensor=false&components=country:mg&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Wolmaransstad, 2630, South Africa
# https://maps.googleapis.com/maps/api/geocode/json?address=wolmaranstad&sensor=false&components=country:za&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Zarakes 340 17, Greece
# https://maps.googleapis.com/maps/api/geocode/json?address=zarakes&sensor=false&components=country:gr&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Bol'shegrivskoye, Omsk Oblast, Russia, 646850
# https://maps.googleapis.com/maps/api/geocode/json?address=bolshegrivskoye&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Aiaki, Kiribati
# https://maps.googleapis.com/maps/api/geocode/json?address=ijaki&sensor=false&components=country:ki&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Longlac, ON P0T, Canada
# https://maps.googleapis.com/maps/api/geocode/json?address=longlac&sensor=false&components=country:ca&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Goderich, Sierra Leone
# https://maps.googleapis.com/maps/api/geocode/json?address=goderich&sensor=false&components=country:sl&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: 96100 Syracuse, Province of Syracuse, Italy
# https://maps.googleapis.com/maps/api/geocode/json?address=syracuse&sensor=false&components=country:it&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Japurá - State of Amazonas, 69495-000, Brazil
# https://maps.googleapis.com/maps/api/geocode/json?address=japura&sensor=false&components=country:br&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Tuvalu
# https://maps.googleapis.com/maps/api/geocode/json?address=asau&sensor=false&components=country:tv&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Santa María Huazolotitlán, Oax., Mexico
# https://maps.googleapis.com/maps/api/geocode/json?address=huazolotitlan&sensor=false&components=country:mx&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Scottburgh, 4180, South Africa
# https://maps.googleapis.com/maps/api/geocode/json?address=scottsburgh&sensor=false&components=country:za&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Khonuu, Sakha Republic, Russia, 678860
# https://maps.googleapis.com/maps/api/geocode/json?address=khonuu&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Parras de la Fuente, Coahuila, Mexico
# https://maps.googleapis.com/maps/api/geocode/json?address=parras&sensor=false&components=country:mx&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Laguna - State of Santa Catarina, Brazil
# https://maps.googleapis.com/maps/api/geocode/json?address=laguna&sensor=false&components=country:br&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: M'Rirt, Morocco
# https://maps.googleapis.com/maps/api/geocode/json?address=mrirt&sensor=false&components=country:ma&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Chagda, Sakha Republic, Russia, 678915
# https://maps.googleapis.com/maps/api/geocode/json?address=chagda&sensor=false&components=country:ru&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Acaraú - State of Ceará, Brazil
# https://maps.googleapis.com/maps/api/geocode/json?address=acarau&sensor=false&components=country:br&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: 98100 Kemijärvi, Finland
# https://maps.googleapis.com/maps/api/geocode/json?address=kemijarvi&sensor=false&components=country:fi&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Requena, Peru
# https://maps.googleapis.com/maps/api/geocode/json?address=requena&sensor=false&components=country:pe&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo
#
#
# Location: Gīnda, Eritrea
# https://maps.googleapis.com/maps/api/geocode/json?address=ginda&sensor=false&components=country:er&key=AIzaSyAA-mCwaBCLqMQVd_VOfNZ5BDTJ-kgAzTo

# %% [markdown]
# ## Perform Second Round of Open Weather Map API Calls

# %%
# Attempting weather search again with lat/lng from geocode of cities orignally not found
# Want to remove any chance that a city or country code misspelling/special character prevented a proper data return
# Verifying true unavailability of weather data
new_not_found = []
new_found = []
new_weather = []

for x in range(len(geocode_found)):
    lat = geocode_found[x]['latitude']
    lng = geocode_found[x]['longitude']
    location_url = f"{url}&lat={lat}&lon{lng}"

    response = requests.get(location_url).json()
    try:
        temp = response['main']['temp_max']
        humidity = response['main']['humidity']
        cloudiness = response['clouds']['all']
        windSpeed = response['wind']['speed']
        locationLat = response['coord']['lat']
        locationLng = response['coord']['lon']
        name = response['name']
        country = response['sys']['country']
        date = response['dt']
        numId = response['id']
        information = {
            'city': name,
            'country': country,
            'ID': numId,
            'date': date,
            'temperature': temp,
            'humidity': humidity,
            'cloudiness': cloudiness,
            'wind speed': windSpeed,
            'latitude': locationLat,
            'longitude': locationLng
        }
        with open(output_txt_file, "a") as myfile:
            myfile.write(f"City weather found using Geocode Lat/Lng\n")
            myfile.write(f"Location: {name}, {country}. City ID: {numId}\n")
            myfile.write(f"{location_url}\n")
            myfile.write("\n")        
        print(f"Location: {name}, {country}")
        print(f"ID: {numId}")
        new_found.append(geocode_found[x]['search term'])
        new_weather.append(information)
        del geocode_found[x]
    except KeyError:
        print(f"{geocode_found[x]['location']} has no data. Skipping!")
        new_not_found.append(geocode_found[x]['search term'])
print("\n")
print(f"Locations Checked: {len(geocode_found)}")
print(f"New weather Results: {len(new_found)}")
print(f"Still not found: {len(new_not_found)}")
print("\n")
# Out:
# Mys Shmidta, Chukotka Autonomous Okrug, Russia, 689350 has no data. Skipping!
# Mata'ura, French Polynesia has no data. Skipping!
# Samusu, Samoa has no data. Skipping!
# Krong Samraong, Cambodia has no data. Skipping!
# Attawapiskat, ON, Canada has no data. Skipping!
# Sale'aula, Samoa has no data. Skipping!
# Dolbeau-Mistassini, QC, Canada has no data. Skipping!
# Belushya Guba, Arkhangelsk Oblast, Russia has no data. Skipping!
# Villingili, Maldives has no data. Skipping!
# Phan Rang–Tháp Chàm, Ninh Thuan Province, Vietnam has no data. Skipping!
# Taolagnaro, Madagascar has no data. Skipping!
# Codrington, Antigua and Barbuda has no data. Skipping!
# Ittoqqortoormiit, Greenland has no data. Skipping!
# Tumanny, Murmansk Oblast, Russia, 184375 has no data. Skipping!
# Touggourt, Algeria has no data. Skipping!
# Ghat, Libya has no data. Skipping!
# Amderma, Nenets Autonomous Okrug, Russia, 166744 has no data. Skipping!
# Zhetikara 110000, Kazakhstan has no data. Skipping!
# 98100 Kemijärvi, Finland has no data. Skipping!
# Requena, Peru has no data. Skipping!
# Gīnda, Eritrea has no data. Skipping!
#
#
# Locations Checked: 80
# New weather Results: 0
# Still not found: 80

# %%
final_found = []
final_weather = []
final_not_found = []

if len(new_found) > 0:
    final_found = found + new_found
else:
    final_found = found
if len(new_weather) > 0:
    final_weather = weather + new_weather
else:
    final_weather = weather
if len(geocode_not_found) > 0:
    final_not_found = new_not_found + geocode_not_found
else: 
    final_not_found = new_not_found

with open(output_txt_file, "a") as myfile:
    myfile.write(f"Final City Count With Weather: {len(final_found)}\n")
    myfile.write(f"Final City Count Without Weather: {len(final_not_found)}\n")
    myfile.write("\n")
print(f"Final City Count With Weather: {len(final_found)}\n")
print(f"Final City Count Without Weather: {len(final_not_found)}\n")
print(f"Number of weather data entries: {len(final_weather)}")
# Out:
# Final City Count With Weather: 537
#
# Final City Count Without Weather: 81
#
# Number of weather data entries: 537

# %% [markdown]
# ## Perform Mapping and Analysis of Sites Without Weather Results

# %%
# Further analysis of cities that weren't found
# Getting coordinates only for cities that returned an exact match on Geocoding search
approximate_cities = []
matched_cities = []
coordinates = []

for city in geocode_found:
    if city['approximate'] == True:
        approximate_cities.append(city)
    else:
        matched_cities.append(city)

for city in matched_cities:
    coordinates.append(f"{float(city['latitude'])}, {float(city['longitude'])}")

coordinates = [tuple(float(y) for y in x.split(',')) for x in coordinates]

# %%
# Mapping locations of cities with exact matches in Google Geocode and Open Weather API but had no weather results
# Initialize and set maps figure 
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout)

# Assign the marker layer to a variable
markers = gmaps.marker_layer(
    coordinates, 
    info_box_content=[f"Location: {city['location']}" for city in matched_cities]
)

# Add the layer to the map
fig.add_layer(markers)
print(f"There were {len(geocode_not_found) + len(approximate_cities)} cities with no exact match found searching"\
     " either Google Geocoding or Open Weather Map.")
print(f"There were {len(matched_cities)} cities with no weather results, but returned an exact Google Geocoding search result.")
print(f"These {len(matched_cities)} cities are mapped below.")
fig
# Out:
# There were 9 cities with no exact match found searching either Google Geocoding or Open Weather Map.
# There were 72 cities with no weather results, but returned an exact Google Geocoding search result.
# These 72 cities are mapped below.
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# Getting a list of countries for the cities without returned weather data
loc_name_split = []
no_weather_country_list = []

# Clean-up locations names collected from Geocode search
# There is a variety of naming conventions pulled from Geocoding (city, country, postal code)
# Splitting each name to eventually pull out the country name
for city in matched_cities:
    loc_name_split.append(city['location'].replace(', ', ',').split(','))

# Country names are either the final item in list or second to last with postal code being the last
for city in loc_name_split:
    country = city[len(city)-1]
    try:
        int(country)
        country = city[len(city)-2]
        no_weather_country_list.append(country)
    except ValueError:
        no_weather_country_list.append(country)

# On rare occasion the name collected from the Geocode search is not comma separated
# (eg: Sakaka Saudi Arabia instead of Sakaka, Saudi Arabia)
# Doing a spot manual clean-up of such instances
# print(no_weather_country_list)
no_weather_country_list[27]="Saudi Arabia"

# Getting counts for unique countries in list using numpy
unique, counts = np.unique(no_weather_country_list, return_counts=True)

country_counts = {
    'Country' : list(unique), 
    'No Weather Count' : list(counts)
}

# Inserting count data into pandas dataframe
no_weather_df = pd.DataFrame(country_counts).set_index('Country')
no_weather_df.head()
# Out:
#                      No Weather Count
# Country
# Algeria                             2
# Antigua and Barbuda                 1
# Brazil                              5
# Cambodia                            1
# Canada                              5

# %%
label = no_weather_df.index
index = np.arange(0, len(label), 1)

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 13
fig_size[1] = 8.67
plt.bar(no_weather_df.index, no_weather_df['No Weather Count'], align='center', color='g')
plt.xlabel("Countries", fontsize=10)
plt.xticks(index, label, rotation=45, fontsize=10, horizontalalignment='right')
plt.ylabel("Count", fontsize=10)
plt.title("Countries With No Weather Data", fontsize=15)

plt.show()

# %% [markdown]
# ## Perform Analysis of Cities With Returned Weather Data

# %%
weather_df = pd.DataFrame(weather).set_index('city')
weather_df = weather_df[['country', 'ID', 'date', 'cloudiness', 'humidity', 'latitude', 'longitude', 'temperature', 'wind speed']]
weather_df.head()
# Out:
#              country       ID        date  cloudiness  humidity  latitude  \
# city
# Grand Gaube       MU   934479  1535061600          75        83    -20.01
# Albany            AU  2077963  1535063622           0        88    -35.02
# Puerto Ayora      EC  3652764  1535061600          75        64     -0.74
# Kavaratti         IN  1267390  1535063623          68        95     10.57
# Kuryk             KZ   609919  1535063623           0        65     43.18
#
#               longitude  temperature  wind speed
# city
# Grand Gaube       57.66        69.80        6.93
# Albany           117.88        43.27        4.36
# Puerto Ayora     -90.35        75.20       17.22
# Kavaratti         72.64        82.51       16.89
# Kuryk             51.68        67.66       12.08

# %%
weather_df.loc[(weather_df['humidity'] > 100) | (weather_df['cloudiness'] > 100), :]
# Out:
#            country       ID        date  cloudiness  humidity  latitude  \
# city
# Bellavista      PE  3699364  1535061600          20       290     -7.06
#
#             longitude  temperature  wind speed
# city
# Bellavista     -76.59         89.6       13.87

# %%
weather_df = weather_df.drop(['Bellavista'])

# %%
plt.scatter(weather_df['latitude'], weather_df['temperature'])
plt.title('City Latitude v. Max Temperature (Aug, 23 2018)', fontsize=15)
plt.xlabel('Latitude', fontsize=15)
plt.ylabel('Temperature (F)', fontsize=15)
# Out:
# Text(0,0.5,'Temperature (F)')

# %%
plt.scatter(weather_df['latitude'], weather_df['humidity'])
plt.title('City Latitude v. Humidity (Aug, 23 2018)', fontsize=15)
plt.xlabel('Latitude', fontsize=15)
plt.ylabel('Humidity (%)', fontsize=15)
# Out:
# Text(0,0.5,'Humidity (%)')

# %%
plt.scatter(weather_df['latitude'], weather_df['cloudiness'])
plt.title('City Latitude v. Cloudiness (Aug, 23 2018)', fontsize=15)
plt.xlabel('Latitude', fontsize=15)
plt.ylabel('Cloudiness (%)', fontsize=15)
# Out:
# Text(0,0.5,'Cloudiness (%)')

# %%
plt.scatter(weather_df['latitude'], weather_df['wind speed'])
plt.title('City Latitude v. Wind Speed (Aug, 23 2018)', fontsize=15)
plt.xlabel('Latitude', fontsize=15)
plt.ylabel('Wind Speed (mph)', fontsize=15)
# Out:
# Text(0,0.5,'Wind Speed (mph)')

# %%
# Out:
#           ID        city  cloudiness country        date  humidity  latitude  \
# 271  3699364  Bellavista          20      PE  1535061600       290     -7.06
#
#      longitude  temperature  wind speed
# 271     -76.59         89.6       13.87
